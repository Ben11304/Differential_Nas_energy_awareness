# %%
# !python train_search.py --batch_size 2 --epochs 300 --device mps --learning_rate 0.01 --arch_learning_rate 0.01
# Out:
# 05/25 05:42:52 PM args = Namespace(data='../data', batch_size=2, learning_rate=0.01, learning_rate_min=0.001, snn_step=5, momentum=0.9, weight_decay=0.0003, report_freq=50, device='mps', epochs=300, init_channels=16, layers=3, model_path='saved_models', cutout=False, cutout_length=16, drop_path_prob=0.3, save='./log/', seed=2, grad_clip=5, train_portion=0.5, unrolled=False, arch_learning_rate=0.01, arch_weight_decay=0.001, rate=[1, 0])
# 05/25 05:42:52 PM param size = 0.219290MB
# wandb: Currently logged in as: huydv6210 (huy_ben) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /Users/duongviethuy/Working_space/Nas_energy/Differential_Nas_energy_awareness/wandb/run-20250525_174253-pmsk4ln3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run search-20250525-174252
# wandb: ⭐️ View project at https://wandb.ai/huy_ben/nas-search
# ...

# %%
# !pip install snntorch
