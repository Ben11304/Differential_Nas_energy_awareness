# %%
# !python train_search.py --batch_size 2 --epochs 300 --device mps --learning_rate 0.01 --arch_learning_rate 0.01
# Out:
# Traceback (most recent call last):
#   File "/Users/duongviethuy/Working_space/Nas_energy/Differential_Nas_energy_awareness/train_search.py", line 6, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install snntorch
# Out:
# Collecting snntorch
#   Downloading snntorch-0.9.4-py2.py3-none-any.whl.metadata (15 kB)
# Downloading snntorch-0.9.4-py2.py3-none-any.whl (125 kB)
# Installing collected packages: snntorch
# Successfully installed snntorch-0.9.4
