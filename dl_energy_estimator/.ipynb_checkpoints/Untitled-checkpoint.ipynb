# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached matplotlib-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
#   Using cached numpy-1.23.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# ...
#   Using cached seaborn-0.12.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached ptflops-0.6.9.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached torchvision-0.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (10 kB)
# ...
#   Using cached codecarbon-2.1.3-py3-none-any.whl.metadata (18 kB)
# ...

# %%
# !python run_data_collection.py
# Out:
# Loading [conv2d] data-collector
# Loading [linear] data-collector
# Loading [maxpool2d] data-collector
# Loading [relu] data-collector
# Loading [sigmoid] data-collector
# Loading [tanh] data-collector
# Loading [softmax] data-collector
# Loading [architectures] data-collector
#
# Starting data-collection for conv2d...
# Total number of iterations:  1500
# Min. runtime: 14.58h
# Doing random configs...
#
# 0/1 (config_no/rep_no) [batch_size:30,image_size:217,kernel_size:11,in_channels:56,out_channels:13,stride:4,padding:0,freeText:] (0.0% done)
# [codecarbon ERROR @ 11:36:57] Unable to read Intel RAPL files for CPU power, we will use a constant for your CPU power. Please view https://github.com/mlco2/codecarbon/issues/244 for workarounds : [Errno 13] Permission denied: '/sys/class/powercap/intel-rapl/intel-rapl:0/energy_uj'
# ...
